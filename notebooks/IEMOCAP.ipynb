# %%
import pandas as pd

# %%
# /home/prsood/projects/def-whkchun/prsood/multi-modal-emotion/data/IEMOCAP_df.pkl
df = pd.read_pickle("../data/IEMOCAP_df.pkl")
df
# Out:
#                                                    text  \
# 0                               What's he going to say?
# 1                                            He saw it.
# 2      How could he see it?  I was the first one up;...
# 3                        He was out here when it broke.
# 4      Four o clock this morning.  I heard a crack a...
# ...                                                 ...
# 7527   Yeah, very amusing.  Let me go.  I'm getting ...
# 7528   You are a vile tempered, loose living, wicked...
# 7529   Oh, marry you again?  I must have been insane...
# 7530   Shut up, shut up.  I wouldn't marry you again...
# 7531                           Beast; brute; cad; whore
#
#                      Session             timings  \
# 0     Ses01F_script01_1_F000        (6.21, 9.32)
# 1     Ses01F_script01_1_M000  (11.9892, 15.1219)
# 2     Ses01F_script01_1_F002  (14.3063, 19.5526)
# 3     Ses01F_script01_1_M001  (19.0456, 22.3962)
# ...

# %%
import torch
new_df = df[ (df['emotion_label'] != "surprised")  & (df['emotion_label'] != "happy")  & (df['emotion_label'] != "fearful")  & (df['emotion_label'] != "other")  & (df['emotion_label'] != "disgusted")   ]
torch.Tensor(list(dict(sorted((dict(1 - (new_df['emotion'].value_counts()/len(df))).items()))).values()))

# %%
df['emotion_label'].value_counts()
# Out:
# frustrated    1849
# neutral       1708
# angry         1103
# sad           1084
# excited       1041
# happy          595
# surprised      107
# fearful         40
# other            3
# disgusted        2
# Name: emotion_label, dtype: int64

# %%
x = [
"surprised",
"fearful"  ,
"other"    ,
"disgusted",
]

# %%
new_df = df[ (df['emotion_label'] != "surprised")  & (df['emotion_label'] != "fearful")  & (df['emotion_label'] != "other")  & (df['emotion_label'] != "disgusted")   ]

# %%
new_df['emotion_label'].value_counts()
# Out:
# frustrated    1849
# neutral       1708
# angry         1103
# sad           1084
# excited       1041
# happy          595
# Name: emotion_label, dtype: int64

# %%
1849+1708+1103+1084+1041+595
# Out:
# 7380

# %%
def speaker(session):
    if session.count('F') == 2 or session.count('M') == 2:
        #Left speaker is talking
        left = True
    else:
        #right speaker is talking
        left = False
    return left

# %%
df['speaker'] = df['Session'].apply(speaker)
df
# Out:
#                                                    text  \
# 0                               What's he going to say?
# 1                                            He saw it.
# 2      How could he see it?  I was the first one up;...
# 3                        He was out here when it broke.
# 4      Four o clock this morning.  I heard a crack a...
# ...                                                 ...
# 7527   Yeah, very amusing.  Let me go.  I'm getting ...
# 7528   You are a vile tempered, loose living, wicked...
# 7529   Oh, marry you again?  I must have been insane...
# 7530   Shut up, shut up.  I wouldn't marry you again...
# 7531                           Beast; brute; cad; whore
#
#                      Session             timings  \
# 0     Ses01F_script01_1_F000        (6.21, 9.32)
# 1     Ses01F_script01_1_M000  (11.9892, 15.1219)
# 2     Ses01F_script01_1_F002  (14.3063, 19.5526)
# 3     Ses01F_script01_1_M001  (19.0456, 22.3962)
# ...

# %%
df['sentiment'] = df['emotion']
df['sentiment_label'] = df['emotion_label']

# %%
df
# Out:
#                                                    text  \
# 0                               What's he going to say?
# 1                                            He saw it.
# 2      How could he see it?  I was the first one up;...
# 3                        He was out here when it broke.
# 4      Four o clock this morning.  I heard a crack a...
# ...                                                 ...
# 7527   Yeah, very amusing.  Let me go.  I'm getting ...
# 7528   You are a vile tempered, loose living, wicked...
# 7529   Oh, marry you again?  I must have been insane...
# 7530   Shut up, shut up.  I wouldn't marry you again...
# 7531                           Beast; brute; cad; whore
#
#                      Session             timings  \
# 0     Ses01F_script01_1_F000        (6.21, 9.32)
# 1     Ses01F_script01_1_M000  (11.9892, 15.1219)
# 2     Ses01F_script01_1_F002  (14.3063, 19.5526)
# 3     Ses01F_script01_1_M001  (19.0456, 22.3962)
# ...

# %%
df.to_pickle("../data/IEMOCAP_df.pkl")

# %%
df
# Out:
#                                                    text  \
# 0                               What's he going to say?
# 1                                            He saw it.
# 2      How could he see it?  I was the first one up;...
# 3                        He was out here when it broke.
# 4      Four o clock this morning.  I heard a crack a...
# ...                                                 ...
# 7527   Yeah, very amusing.  Let me go.  I'm getting ...
# 7528   You are a vile tempered, loose living, wicked...
# 7529   Oh, marry you again?  I must have been insane...
# 7530   Shut up, shut up.  I wouldn't marry you again...
# 7531                           Beast; brute; cad; whore
#
#                      Session             timings  \
# 0     Ses01F_script01_1_F000        (6.21, 9.32)
# 1     Ses01F_script01_1_M000  (11.9892, 15.1219)
# 2     Ses01F_script01_1_F002  (14.3063, 19.5526)
# 3     Ses01F_script01_1_M001  (19.0456, 22.3962)
# ...

# %%
# /home/prsood/projects/def-whkchun/prsood/multi-modal-emotion/data/IEMOCAP_df.pkl
df = pd.read_pickle("../data/IEMOCAP_df.pkl")
df
# Out:
#                                                    text  \
# 0                               What's he going to say?
# 1                                            He saw it.
# 2                        He was out here when it broke.
# 3      Four o clock this morning.  I heard a crack a...
# 4                                         I don't know.
# ...                                                 ...
# 7375      [LAUGHTER] That was quit a rouser, wasn't it?
# 7376                    Oh, I didn't hit you very hard.
# 7377         I should never forget his face. [LAUGHTER]
# 7378                    We were very much younger then.
# 7379                You knew there was nothing in that.
#
#                      Session             timings  \
# 0     Ses01F_script01_1_F000        (6.21, 9.32)
# 1     Ses01F_script01_1_M000  (11.9892, 15.1219)
# 2     Ses01F_script01_1_M001  (19.0456, 22.3962)
# 3     Ses01F_script01_1_M002     (24.8, 35.9971)
# ...

# %%
import numpy as np
x = np.array([[ 599, 1049,  623],
        [ 676, 3122,  626],
        [ 604,  912,  661]]) # Original glad-sweep-31
y = np.array([[ 599, 1049,  623],
        [ 676, 3122,  626],
        [ 604,  912,  661]])
x.sum(),y.sum()
# Out:
# (8872, 8872)

# %%
8880/4/4
# Out:
# 555.0

# %%
9211/4
# Out:
# 2302.75

# %%
9834 - 8880
# Out:
# 954

# %%
df = pd.read_pickle("../data/text_audio_video_emotion_data.pkl")
df = df[ (df['emotion_label'] != "fear")  & (df['emotion_label'] != "disgust")]
df = df[~df['timings'].isna()] # Still seeing what the best configuration is for these
len(df[df['split'] == 'train']),len(df[df['split'] == 'val'])
# Out:
# (9211, 1025)

# %%
df = pd.read_pickle("../data/text_audio_video_emotion_data.pkl")
# df = df[ (df['emotion_label'] != "fear")  & (df['emotion_label'] != "disgust")]
len(df[df['split'] == 'train']),len(df[df['split'] == 'val'])
# Out:
# (9834, 1097)

# %%
df['speaker'].value_counts()
# Out:
# True     3847
# False    3685
# Name: speaker, dtype: int64

# %%
x = "../../data/iemocap_wav/Ses01F_script01_1_F000.wav"

x.replace("_F000.wav"  , ".avi")
# Out:
# '../../data/iemocap_wav/Ses01F_script01_1.avi'
